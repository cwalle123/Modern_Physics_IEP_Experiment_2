# %% [markdown]
# Grating is 1800 mm and 500nm
# Slid is at 10 (1 mm) - 2 rotations from closed
# Distance from Slid to First Lens = 21.1 ± 0.1 cm -> Focal Length of 200 mm
# Distance from Screen to Second Lens = 8.1 cm ± 0.1 cm -> Focal Length of 100 mm
#
#
#
# When i=0, angle scale shows 53 ± 1 degrees
# The 0th order, angle scale shows 59 ± 1 degrees
# Alpha is the difference between those two or 6 ± 1.4  angle
#
# The 1st order, angle scale shows 92 ± 1degrees
# Phi is the difference between first order and i = 0, thus phi = 39 ± 1.4 degrees
#
# ## Spectral Line Data
#
# | Colour | Order m | Reading (°) | φ (°) | λ (nm) | u(λ) (nm) and Preparation Q10 |
# |---|---:|---:|---:|---:|---|
# | Yellow | -1 | 92 ± 1 | | | |
# | Green | -1 | 90 +- 1| | | |
# | | | | | | |
# | | | | | | |
