# %% [markdown]
# Grating is 1800 mm and 500nm
# Slit is at 10 (1 mm) - 2 rotations from closed
# Distance from Slit to First Lens = 21.1 ± 0.1 cm -> Focal Length of 200 mm
# Distance from Screen to Second Lens = 8.1 cm ± 0.1 cm -> Focal Length of 100 mm
